# %%
import pandas as pd
import numpy as np


from bokeh.plotting import figure, output_file, show
from bokeh.models.widgets import Dropdown
from bokeh.layouts import widgetbox
from bokeh.charts import Bar, Histogram
from bokeh.io import *
from bokeh.palettes import Spectral6
from bokeh import mpl


output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="921cacb3-52a3-4d7b-9685-1a2d0eb1aaa7">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv('NEWER_Clean_df.csv', index_col=0)

# %%
d = {0: 'Not Fraud',
     1: 'Fraud'}

# %%
new_df = df[df['event_created_to_end'] < 15]

# %%
new_df.replace({'label': d}, inplace=True)

# %%
new_df['label'].unique()
# Out:
# array(['Fraud', 'Not Fraud'], dtype=object)

# %%
new_df['color_set'] = ['#FF8C00' if element == 'Fraud' else '#FAFCCC' for element in np.array(new_df['label'])]
# Out:
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
new_df
# Out:
#            label  channels  delivery_method  show_map  user_type  has_logo  \
# 26         Fraud        11              0.0         0          3         0
# 38     Not Fraud         5              0.0         0          3         1
# 41     Not Fraud         8              0.0         0          3         1
# 43     Not Fraud        11              0.0         1          3         1
# 54         Fraud        11              0.0         0          1         1
# 61     Not Fraud         6              0.0         1          3         1
# 63     Not Fraud         6              0.0         1          4         1
# 64     Not Fraud         5              0.0         1          1         1
# 68     Not Fraud         6              0.0         1          4         1
# 80     Not Fraud         0              0.0         1          1         1
# 84     Not Fraud         0              0.0         0          3         1
# 92     Not Fraud         0              0.0         0          5         1
# 96     Not Fraud         6              0.0         1          4         1
# 98     Not Fraud        11              1.0         0          3         1
# 104    Not Fraud         5              0.0         1          1         1
# 115    Not Fraud         5              0.0         1          3         1
# 128        Fraud         0              0.0         1          1         1
# 130        Fraud         6              0.0         0          3         1
# 131        Fraud        11              0.0         1          1         1
# 136    Not Fraud        11              0.0         1          4         1
# 140        Fraud         6              0.0         0          3         1
# 144        Fraud        13              0.0         1          1         1
# 149        Fraud         5              0.0         1          1         0
# 154    Not Fraud         0              0.0         1          4         0
# 161        Fraud         5              0.0         1          1         0
# 168    Not Fraud         0              0.0         1          3         1
# 171    Not Fraud         5              0.0         1          3         1
# 176    Not Fraud         0              1.0         1          3         1
# 177        Fraud         5              0.0         1          1         1
# 181        Fraud         6              0.0         1          1         1
# ...          ...       ...              ...       ...        ...       ...
# 14129  Not Fraud         0              1.0         1          1         1
# 14131      Fraud         5              0.0         1          1         0
# 14140      Fraud         5              0.0         1          1         1
# 14149      Fraud         6              0.0         1          1         1
# 14151  Not Fraud         0              1.0         1          3         0
# 14161  Not Fraud         6              0.0         1          3         0
# 14164      Fraud        10              0.0         1          1         1
# 14165  Not Fraud         8              0.0         1          3         1
# 14166  Not Fraud         0              0.0         0          4         1
# 14168  Not Fraud         0              0.0         0          5         1
# 14179  Not Fraud         8              0.0         1          1         1
# 14185  Not Fraud         0              1.0         1          3         0
# 14215  Not Fraud        11              1.0         1          3         1
# 14219  Not Fraud         4              0.0         1          3         0
# 14229      Fraud         5              0.0         1          3         0
# 14243  Not Fraud         8              1.0         0          4         0
# 14251      Fraud         5              0.0         1          1         0
# 14255      Fraud         0              0.0         1          1         1
# 14257  Not Fraud         8              1.0         1          3         1
# 14258  Not Fraud         6              0.0         1          3         1
# 14259  Not Fraud         0              1.0         1          4         1
# 14271      Fraud         0              0.0         1          1         1
# 14279  Not Fraud        11              0.0         1          4         1
# 14280  Not Fraud         4              0.0         1          3         1
# 14286  Not Fraud         6              0.0         1          1         1
# 14313  Not Fraud         5              0.0         1          4         0
# 14316      Fraud         4              0.0         1          1         1
# 14318      Fraud         0              0.0         1          1         1
# 14325      Fraud         0              0.0         1          1         1
# 14332      Fraud         0              0.0         1          1         1
#
#        org_facebook  sale_duration  sale_duration2  event_created_to_end  \
# 26              0.0            0.0               0                     0
# 38             16.0            9.0               9                     9
# 41              0.0           12.0              12                    12
# 43              0.0            0.0               0                     0
# 54              0.0            6.0               6                     7
# 61              0.0           13.0              13                    13
# 63             20.0            8.0               8                     9
# 64              0.0            8.0               8                     8
# 68              0.0           10.0              10                    10
# 80              0.0           14.0              14                    14
# 84              0.0            0.0               0                     0
# 92              0.0            1.0               1                     1
# 96             11.0            9.0               9                     9
# 98              5.0            3.0               3                     3
# 104             0.0           10.0              10                    10
# 115             0.0           13.0              13                    13
# 128             0.0            9.0               9                    11
# 130             0.0            0.0               0                     1
# 131             0.0            4.0               4                     4
# 136             0.0           10.0              10                    10
# 140             0.0            1.0               1                     1
# 144             0.0            5.0               5                     7
# 149             0.0           -3.0               0                    -1
# 154            18.0            0.0               0                    10
# 161             0.0           11.0              11                    11
# 168            11.0            4.0               4                     4
# 171            17.0           12.0              12                    12
# 176             0.0            0.0               0                    11
# 177             0.0            1.0               1                     0
# 181             0.0            5.0               5                     5
# ...             ...            ...             ...                   ...
# 14129           0.0            9.0              12                    12
# 14131           0.0            6.0               6                     6
# 14140           0.0            4.0               4                     4
# 14149           0.0            9.0               9                     9
# 14151           0.0            0.0               0                     0
# 14161          11.0            1.0               1                     6
# 14164           0.0            9.0               9                     9
# 14165           0.0           11.0              11                    11
# 14166          14.0            6.0               6                     6
# 14168           0.0            2.0               2                     2
# 14179          10.0           11.0              11                    11
# 14185           0.0           14.0              14                    14
# 14215           0.0            0.0               0                     5
# 14219           0.0            7.0               7                     7
# 14229           0.0            5.0               5                     5
# 14243          11.0           13.0              13                    13
# 14251           0.0            1.0               1                     3
# 14255           0.0            4.0               7                     7
# 14257          20.0           13.0              13                    13
# 14258          12.0           13.0              13                    13
# 14259           0.0           11.0              11                    11
# 14271          23.0           12.0              12                    12
# 14279           0.0           11.0              11                    11
# 14280          10.0            2.0               2                     2
# 14286           0.0            9.0              10                    10
# 14313           9.0            0.0               0                     1
# 14316           0.0            9.0              10                    11
# 14318           0.0            4.0               4                     4
# 14325           0.0            2.0               2                     2
# 14332           0.0           11.0              11                    11
#
#        num_ticket_type  median_ticket_cost  total_tickets_sold  \
# 26                 2.0             250.000                   2
# 38                 1.0              15.000                 109
# 41                 5.0              25.000                  14
# 43                 4.0              45.000                   1
# 54                 1.0             500.000                   0
# 61                 7.0              15.000                 491
# 63                 1.0              12.850                   2
# 64                 1.0              35.000                  34
# 68                 1.0               5.000                   1
# 80                 1.0             250.000                  30
# 84                 1.0            4112.550                   1
# 92                 1.0             250.000                   1
# 96                 4.0              14.000                  12
# 98                 1.0               0.000                  15
# 104                1.0              15.000                   3
# 115                4.0              17.000                   6
# 128                2.0             300.000                   9
# 130                1.0             140.760                   1
# 131                3.0             350.000                   3
# 136                2.0               0.000                   2
# 140                1.0             140.760                   3
# 144                7.0             190.000                   2
# 149                2.0              91.875                   0
# 154                8.0              75.000                  16
# 161                1.0               8.460                   1
# 168                1.0              25.000                   5
# 171                3.0              10.000                  12
# 176               17.0              30.000                   2
# 177                1.0             100.000                   0
# 181                4.0             160.000                   0
# ...                ...                 ...                 ...
# 14129              3.0              35.000                   4
# 14131              1.0              10.000                  19
# 14140              1.0              50.000                 129
# 14149              1.0               0.000                   0
# 14151              2.0             112.500                   3
# 14161              2.0              10.155                   2
# 14164              4.0             375.000                   3
# 14165              1.0              64.210                  11
# 14166              1.0               8.510                  56
# 14168              1.0              35.000                   1
# 14179              1.0              15.000                   6
# 14185              2.0              20.010                  28
# 14215              1.0               0.000                   1
# 14219              1.0               8.460                  10
# 14229              2.0             140.000                   0
# 14243              4.0               4.040                  59
# 14251              1.0            1000.000                   0
# 14255              2.0             117.135                   0
# 14257              2.0               5.000                   6
# 14258              2.0              15.000                   8
# 14259              3.0              20.740                 109
# 14271              3.0              40.000                   1
# 14279              3.0              15.000                  77
# 14280              1.0              45.000                  23
# 14286              1.0              55.710                   1
# 14313              3.0              21.000                  50
# 14316              1.0             120.000                   0
# 14318              1.0              55.000                   0
# 14325              1.0             649.650                   0
# 14332              1.0              45.000                   0
#
#       nan_delivery_method nan_org_facebook nan_num_ticket_type  \
# 26                  False            False               False
# 38                  False            False               False
# 41                  False            False               False
# 43                  False            False               False
# 54                  False            False               False
# 61                  False            False               False
# 63                  False            False               False
# 64                  False            False               False
# 68                  False            False               False
# 80                  False            False               False
# 84                  False            False               False
# 92                  False            False               False
# 96                  False            False               False
# 98                  False            False               False
# 104                 False            False               False
# 115                 False            False               False
# 128                 False            False               False
# 130                 False            False               False
# 131                 False            False               False
# 136                 False            False               False
# 140                 False            False               False
# 144                 False            False               False
# 149                 False            False               False
# 154                 False            False               False
# 161                 False            False               False
# 168                 False            False               False
# 171                 False            False               False
# 176                 False            False               False
# 177                 False            False               False
# 181                 False            False               False
# ...                   ...              ...                 ...
# 14129               False            False               False
# 14131               False            False               False
# 14140               False            False               False
# 14149               False            False               False
# 14151               False            False               False
# 14161               False            False               False
# 14164               False            False               False
# 14165               False            False               False
# 14166               False            False               False
# 14168               False            False               False
# 14179               False            False               False
# 14185               False            False               False
# 14215               False            False               False
# 14219               False            False               False
# 14229               False            False               False
# 14243               False            False               False
# 14251               False            False               False
# 14255               False            False               False
# 14257               False            False               False
# 14258               False            False               False
# 14259               False            False               False
# 14271               False            False               False
# 14279               False            False               False
# 14280               False            False               False
# 14286               False            False               False
# 14313               False            False               False
# 14316               False            False               False
# 14318               False            False               False
# 14325               False            False               False
# 14332               False            False               False
#
#       nan_median_ticket_cost  payout_type_CHECK  payout_type_MISSING color_set
# 26                     False                  0                    0   #FF8C00
# 38                     False                  0                    0   #FAFCCC
# 41                     False                  0                    0   #FAFCCC
# 43                     False                  1                    0   #FAFCCC
# 54                     False                  0                    0   #FF8C00
# 61                     False                  0                    0   #FAFCCC
# 63                     False                  0                    0   #FAFCCC
# 64                     False                  0                    0   #FAFCCC
# 68                     False                  0                    0   #FAFCCC
# 80                     False                  0                    0   #FAFCCC
# 84                     False                  0                    0   #FAFCCC
# 92                     False                  0                    0   #FAFCCC
# 96                     False                  1                    0   #FAFCCC
# 98                     False                  0                    0   #FAFCCC
# 104                    False                  0                    0   #FAFCCC
# 115                    False                  0                    0   #FAFCCC
# 128                    False                  0                    0   #FF8C00
# 130                    False                  0                    0   #FF8C00
# 131                    False                  0                    0   #FF8C00
# 136                    False                  1                    0   #FAFCCC
# 140                    False                  0                    0   #FF8C00
# 144                    False                  0                    0   #FF8C00
# 149                    False                  0                    0   #FF8C00
# 154                    False                  0                    0   #FAFCCC
# 161                    False                  0                    0   #FF8C00
# 168                    False                  0                    0   #FAFCCC
# 171                    False                  0                    0   #FAFCCC
# 176                    False                  0                    0   #FAFCCC
# 177                    False                  0                    0   #FF8C00
# 181                    False                  0                    0   #FF8C00
# ...                      ...                ...                  ...       ...
# 14129                  False                  0                    0   #FAFCCC
# 14131                  False                  1                    0   #FF8C00
# 14140                  False                  0                    0   #FF8C00
# 14149                  False                  0                    1   #FF8C00
# 14151                  False                  0                    0   #FAFCCC
# 14161                  False                  1                    0   #FAFCCC
# 14164                  False                  0                    0   #FF8C00
# 14165                  False                  0                    0   #FAFCCC
# 14166                  False                  1                    0   #FAFCCC
# 14168                  False                  0                    0   #FAFCCC
# 14179                  False                  0                    0   #FAFCCC
# 14185                  False                  0                    0   #FAFCCC
# 14215                  False                  0                    0   #FAFCCC
# 14219                  False                  0                    0   #FAFCCC
# 14229                  False                  0                    0   #FF8C00
# 14243                  False                  0                    0   #FAFCCC
# 14251                  False                  0                    0   #FF8C00
# 14255                  False                  0                    0   #FF8C00
# 14257                  False                  0                    0   #FAFCCC
# 14258                  False                  0                    0   #FAFCCC
# 14259                  False                  0                    0   #FAFCCC
# 14271                  False                  0                    0   #FF8C00
# 14279                  False                  0                    0   #FAFCCC
# 14280                  False                  0                    0   #FAFCCC
# 14286                  False                  0                    0   #FAFCCC
# 14313                  False                  0                    0   #FAFCCC
# 14316                  False                  0                    0   #FF8C00
# 14318                  False                  0                    1   #FF8C00
# 14325                  False                  0                    1   #FF8C00
# 14332                  False                  0                    1   #FF8C00
#
# [2577 rows x 20 columns]

# %%
new_df

# %%
fcreate = new_df[new_df['label'] == 'Fraud']['event_created_to_end']
tcreate = new_df[new_df['label'] == 'Not Fraud']['event_created_to_end']

# %%
def bokeh_widget(selected_feature = 'event_created_to_end', bins = 15):
    color_list = ['#FF8C00', '#FAFCCC', '#EA653B', '#EE993D', \
                      '#EA653B','#ED9239', '#A4A7AA', '#676767']

    TOOLS = "pan,wheel_zoom,box_zoom,reset,save,box_select"

    p = figure(width=500, height=500, tools = TOOLS)

    p = Histogram(new_df, 
                  values = selected_feature, 
                  label = 'label',
                  color = 'label',
                  title = selected_feature,
                  density = True,
                  legend = 'top_right',
                  bins = bins, 
                  palette = color_list)

    p.xaxis.axis_label_text_font_style = 'normal'
    p.yaxis.axis_label_text_font_style = 'normal'
    p.xaxis.axis_label_text_font_size = '18pt'
    p.yaxis.axis_label_text_font_size = '18pt'


    p.background_fill_color = "#acaaa8"
    p.background_fill_alpha = 0.5
    p.title.text_font = 'helvetica'
    p.title.text_font_size = '18pt'
    p.legend

    show(p, notebook_handle=True)
    
    
output_file("bokeh_widget.html")
menu = [("Event Created to End", "event_create_to_end"), ("Tickets Sold", "total_tickets_sold"),\
        ("Missing Payout Type?", "payout_type_MISSING"), ("Median Ticket Cost", "median_ticket_cost")]
dropdown = Dropdown(label="Select Feature", button_type="warning", menu=menu)

def function_to_call(attr, old, new):
    print dropdown.value
  
    

dropdown.on_change('value', function_to_call)
dropdown.on_click(function_to_call)


show(widgetbox(dropdown), notebook_handle=True)
# Out:
# INFO:bokeh.core.state:Session output file 'bokeh_widget.html' already exists, will be overwritten.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e6c7c614-1722-48a3-a9c4-cb6de3c45c41"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e6c7c614-1722-48a3-a9c4-cb6de3c45c41").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("34b173e2-1ee1-41e2-886d-51e26d6c8aef", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e6c7c614-1722-48a3-a9c4-cb6de3c45c41");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e6c7c614-1722-48a3-a9c4-cb6de3c45c41' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5e48a4c6-6690-42e1-8e31-9f2c9deb5a0d":{"roots":{"references":[{"attributes":{"button_type":"warning","callback":null,"icon":null,"label":"Select Feature","menu":[["Event Created to End","event_create_to_end"],["Tickets Sold","total_tickets_sold"],["Missing Payout Type?","payout_type_MISSING"],["Median Ticket Cost","median_ticket_cost"]]},"id":"cb8e87f0-5b46-473d-8319-980c47a9bfcf","type":"Dropdown"},{"attributes":{"children":[{"id":"cb8e87f0-5b46-473d-8319-980c47a9bfcf","type":"Dropdown"}]},"id":"3b0f219f-de15-40e0-bfe4-101615c00c2e","type":"WidgetBox"}],"root_ids":["3b0f219f-de15-40e0-bfe4-101615c00c2e"]},"title":"Bokeh Application","version":"0.12.4"}};
#             var render_items = [{"docid":"5e48a4c6-6690-42e1-8e31-9f2c9deb5a0d","elementid":"e6c7c614-1722-48a3-a9c4-cb6de3c45c41","modelid":"3b0f219f-de15-40e0-bfe4-101615c00c2e","notebook_comms_target":"34b173e2-1ee1-41e2-886d-51e26d6c8aef"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((window.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i](window.Bokeh);
#         }if (force === true) {
#           display_loaded();
#         }} else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!window._bokeh_failed_load) {
#         console.log("Bokeh: BokehJS failed to load within specified timeout.");
#         window._bokeh_failed_load = true;
#       } else if (force !== true) {
#         var cell = $(document.getElementById("e6c7c614-1722-48a3-a9c4-cb6de3c45c41")).parents('.cell').data().cell;
#         cell.output_area.append_execute_result(NB_LOAD_WARNING)
#       }
#
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[22]</strong>&gt;</code></p>

# %%
bokeh_widget('payout_type_MISSING')
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0dec5e01-3d33-4114-808e-652a2f639ae8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("0dec5e01-3d33-4114-808e-652a2f639ae8").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0dec5e01-3d33-4114-808e-652a2f639ae8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0dec5e01-3d33-4114-808e-652a2f639ae8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"de555071-48d2-4c42-9f7f-0f1e68417822":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(-0.300000, -0.233333]"],"color":["#FAFCCC"],"fill_alpha":[0.6],"height":[0.0],"label":["(-0.300000, -0.233333]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.06666666666666665],"x":["-0.2666665"],"y":[0.0]}},"id":"e668a2bf-e8d6-40c2-b8c6-5c2a70fcca3c","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.466667, 0.533333]"],"color":["#FF8C00"],"fill_alpha":[0.6],"height":[0.0],"label":["(0.466667, 0.533333]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.06666666666666665],"x":["0.5"],"y":[0.0]}},"id":"039a2357-4ae9-4bd0-8ce1-5a81f690a40a","type":"ColumnDataSource"},{"attributes":{},"id":"23907691-573d-4ee8-8017-d61b17c94d4e","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.433333, 0.500000]"],"color":["#FAFCCC"],"fill_alpha":[0.6],"height":[0.0],"label":["(0.433333, 0.500000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.06666666666666665],"x":["0.4666665"],"y":[0.0]}},"id":"a2ff9c59-ae6d-4e19-838f-b4f29a5134a3","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":"payout_type_MISSING","text_font_size":{"value":"18pt"}},"id":"65a838eb-dc34-455f-aaca-3183154d40d0","type":"Title"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.266667, 0.333333]"],"color":["#FF8C00"],"fill_alpha":[0.6],"height":[0.0],"label":["(0.266667, 0.333333]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.06666666666666665],"x":["0.3"],"y":[0.0]}},"id":"0021c9ab-a0d9-447d-9a53-c140bcf20142","type":"ColumnDataSource"},{"attributes":{},"id":"f7f8e0a3-1597-4605-af9f-1e7736d4cb8b","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.233333, 0.300000]"],"color":["#FAFCCC"],"fill_alpha":[0.6],"height":[0.0],"label":["(0.233333, 0.300000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.06666666666666676],"x":["0.2666665"],"y":[0.0]}},"id":"9cb43543-b838-419a-b504-5497a5d76699","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(-0.366667, -0.300000]"],"color":["#FAFCCC"],"fill_alpha":[0.6],"height":[0.0],"label":["(-0.366667, -0.300000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.06666666666666671],"x":["-0.3333335"],"y":[0.0]}},"id":"6582da93-2258-4171-bca6-c61a57217bf0","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.733333, 0.800000]"],"color":["#FF8C00"],"fill_alpha":[0.6],"height":[0.0],"label":["(0.733333, 0.800000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.06666666666666676],"x":["0.7666665"],"y":[0.0]}},"id":"a933764e-9218-4aa2-b33a-c836b468b2ac","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bed02346-aa9a-4edf-b74e-de6ccf270e08","type":"Rect"},{"attributes":{"callback":null,"end":1.0124998333333333,"start":-0.5124998333333333},"id":"334545ee-8f8e-4408-b76b-b713086cfd70","type":"Range1d"},{"attributes":{},"id":"3adb4524-ae25-40d3-b194-ed06494c401f","type":"BasicTickFormatter"},{"attributes" ...

# %%
from bokeh.io import output_file, show
from bokeh.layouts import widgetbox
from bokeh.models.widgets import Dropdown

output_file("dropdown.html")
menu = [("Event Created to End", "event_create_to_end"), ("Tickets Sold", "total_tickets_sold"),\
        ("Missing Payout Type?", "payout_type_missing"), ("Median Ticket Cost", "median_ticket_cost"), ("Sale Duration", "sale_duration")]
dropdown = Dropdown(label="Dropdown button", button_type="warning", menu=menu)

def function_to_call(attr, old, new):
    print dropdown.value

dropdown.on_change('value', function_to_call)
dropdown.on_click(function_to_call)
show(widgetbox(dropdown))

# %%
def plt_bar(lst, test_point_hr = None, kde = True, title = None, grid = True, figsize = (10, 10), \
            xlabel = None, ylabel = 'percentage', extra_colors = [], labels = None):
    
    
    """Takes a list of arrays and 
    plots their histograms on the same graph

    Inputs:
        lst:             list of arrays, each array will have a histogram
        test_point_hr:   shades in bar of predicted hour datapoint, default = None
        kde:             will graph the kde or not graph the kde, default = True
        title:           main title of the plot, default 'None'
        grid:            grid appears if True, no grid if False, default True
        figsize:         size of the plot, default = (10, 10)
        xlabel:          label of x-axis, default = 'None'
        ylabel:          label of y-axis, default = 'percentage'
        extra_colors:    list of other colors to add to the color_list, default = []
        labels:          list of labels for each histogram, default = []

    -------------------
    Returns: a histogram of each array in the list
        """
    color_list = ['#FF8C00', '#FAFCCC', '#EA653B', '#EE993D', \
                  '#EA653B','#ED9239', '#A4A7AA', '#676767']
    
    if extra_colors != []: 
        for c in extra_colors:
            color_list.append(c)
    
    
    if len(lst) > len(color_list):
        print 'Not enough colors for each histogram'
        print 'we will automatically assign them to black'
        print 'Assign {} more colors to fix this problem'.format(len(lst) - len(color_list))
        
    
    fig = plt.figure(figsize=figsize)
    
    if grid:
        plt.grid(zorder = 0, linestyle = 'dashed', color = '#acaaa8')
    
    
    for index, array in enumerate(lst):
        cnt = Counter()
        for hr in array:
            cnt[hr] += 1
        
        xvalues = cnt.keys()
        yvalues = cnt.values()
        bar_list = plt.bar(xvalues, 
                           [yvalue * .001 for yvalue in yvalues],
                           ec = 'k', 
                           color=color_list[index], 
                           zorder = 3,
                           alpha = 0.8)
        if labels:
            bar_list.set_label(labels[index])
        
        if test_point_hr and index == 0:
            bar_list[test_point_hr].set_color('r')
            bar_list[test_point_hr].set_label('Tested Point')
        
        elif test_point_hr and index == 1:
            bar_list[test_point_hr].set_color('r')
        
        
        if kde:
            sns.kdeplot(array,
                        color = '#EA653B',
                        linewidth = 3,
                        zorder = 4, 
                        alpha = 0.8,
                        label = '')
        
        plt.legend()
        if title:
            plt.title(title)
        if xlabel:
            plt.xlabel(xlabel)
        plt.ylabel(ylabel)
    
    
        
    plt.show()

# %%
def total_tickets_sold(x):
    """
    Input: dataframe x with column 'quantity sold'
    ------------
    Returns: Total Number of Tickets sold
    """
    sold = []
    for i in x:
        sold.append(i['quantity_sold'])
    return sum(sold)

def median_ticket_cost(x):
    """
    Input: dataframe x with column called 'cost'
    ----------------
    Returns: median cost
    """
    costs = []

    for i in x:

        costs.append(i['cost'])

    return np.median(costs)

# %%
fcreate = np.array(fcreate)
tcreate = np.array(tcreate)

# %%
plt_bar([fcreate, tcreate], test_point_hr = 11, title = 'Created Date minus End Date', xlabel = 'Duration', \
        labels = ['Fraud', 'Not Fraud'])
